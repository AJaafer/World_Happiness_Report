# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
warnings.filterwarnings("ignore")
#changeable data source
print(os.listdir("C:/Users/mkay/Desktop/GitHub/WH/data"))
# %matplotlib inline
# Out:
# ['2015.csv', '2016.csv', '2017.csv']

# %%
data=pd.read_csv('C:/Users/mkay/Desktop/GitHub/WH/data/2017.csv')
data.head(10)
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
# 5  Netherlands               6            7.377      7.427426     7.326574
# 6       Canada               7            7.316      7.384403     7.247597
# 7  New Zealand               8            7.314      7.379510     7.248490
# 8       Sweden               9            7.284      7.344095     7.223905
# 9    Australia              10            7.284      7.356651     7.211349
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# ...

# %%
#setting up the dirty columns properly
data.columns=['Country', 'Happiness_Rank', 'Happiness_Score', 'Whisker_high',
       'Whisker_low', 'Economy_GDP', 'Family',
       'Health_Life_Expectancy', 'Freedom', 'Generosity',
       'Trust_Government_Corruption', 'Dystopia_Residual']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
# Country                        155 non-null object
# Happiness_Rank                 155 non-null int64
# Happiness_Score                155 non-null float64
# Whisker_high                   155 non-null float64
# Whisker_low                    155 non-null float64
# Economy_GDP                    155 non-null float64
# Family                         155 non-null float64
# Health_Life_Expectancy         155 non-null float64
# Freedom                        155 non-null float64
# Generosity                     155 non-null float64
# Trust_Government_Corruption    155 non-null float64
# Dystopia_Residual              155 non-null float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 14.6+ KB

# %%
data.describe()
# Out:
#        Happiness_Rank  Happiness_Score  Whisker_high  Whisker_low  \
# count      155.000000       155.000000    155.000000   155.000000
# mean        78.000000         5.354019      5.452326     5.255713
# std         44.888751         1.131230      1.118542     1.145030
# min          1.000000         2.693000      2.864884     2.521116
# 25%         39.500000         4.505500      4.608172     4.374955
# 50%         78.000000         5.279000      5.370032     5.193152
# 75%        116.500000         6.101500      6.194600     6.006527
# max        155.000000         7.537000      7.622030     7.479556
#
#        Economy_GDP      Family  Health_Life_Expectancy     Freedom  \
# count   155.000000  155.000000              155.000000  155.000000
# mean      0.984718    1.188898                0.551341    0.408786
# std       0.420793    0.287263                0.237073    0.149997
# min       0.000000    0.000000                0.000000    0.000000
# ...

# %%
plt.boxplot(data.Happiness_Score)
plt.show()

# %%
data.corr()
# Out:
#                              Happiness_Rank  Happiness_Score  Whisker_high  \
# Happiness_Rank                     1.000000        -0.992774     -0.993058
# Happiness_Score                   -0.992774         1.000000      0.999497
# Whisker_high                      -0.993058         0.999497      1.000000
# Whisker_low                       -0.991533         0.999520      0.998036
# Economy_GDP                       -0.813244         0.812469      0.811868
# Family                            -0.736753         0.752737      0.750934
# Health_Life_Expectancy            -0.780716         0.781951      0.776634
# Freedom                           -0.551608         0.570137      0.569907
# Generosity                        -0.132620         0.155256      0.155462
# Trust_Government_Corruption       -0.405842         0.429080      0.426459
# Dystopia_Residual                 -0.484506         0.475355      0.478824
#
#                              Whisker_low  Economy_GDP    Family  \
# ...

# %%
#heatmap of corellation btw columns
f,corr=plt.subplots(figsize=(13,8))
sns.heatmap(data.corr(),annot=True,linewidths=5,fmt=' .1f',ax=corr)
plt.show()

# %%
# Line Plot
data.Freedom.plot(kind = 'line', color = 'purple',label = 'Freedom',linewidth=1,alpha = 0.5,grid = True,linestyle = ':')
data.Happiness_Score.plot(color = 'r',label = 'Score',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')
plt.legend(loc='upper right')     
plt.xlabel('x axis')              
plt.ylabel('y axis')
plt.title('Line Plot')            
plt.show()

# %%
# Scatter Plot 
data.plot(kind='scatter', x='Happiness_Score', y='Freedom',alpha = 0.5,color = 'red')
plt.xlabel('Score')             
plt.ylabel('Freedom')
plt.title('Score-Freedom Scatter')
# Out:
# Text(0.5,1,'Score-Freedom Scatter')

# %%
# Histogram
data.Happiness_Score.plot(kind = 'hist',bins = 50,figsize = (12,12),edgecolor='black')
plt.show()

# %%
data.describe()
# Out:
#        Happiness_Rank  Happiness_Score  Whisker_high  Whisker_low  \
# count      155.000000       155.000000    155.000000   155.000000
# mean        78.000000         5.354019      5.452326     5.255713
# std         44.888751         1.131230      1.118542     1.145030
# min          1.000000         2.693000      2.864884     2.521116
# 25%         39.500000         4.505500      4.608172     4.374955
# 50%         78.000000         5.279000      5.370032     5.193152
# 75%        116.500000         6.101500      6.194600     6.006527
# max        155.000000         7.537000      7.622030     7.479556
#
#        Economy_GDP      Family  Health_Life_Expectancy     Freedom  \
# count   155.000000  155.000000              155.000000  155.000000
# mean      0.984718    1.188898                0.551341    0.408786
# std       0.420793    0.287263                0.237073    0.149997
# min       0.000000    0.000000                0.000000    0.000000
# ...

# %%
melted=pd.melt(frame=data,id_vars='Country',value_vars=['Happiness_Rank','Freedom'])
melted.head(7)
# Out:
#        Country        variable  value
# 0       Norway  Happiness_Rank    1.0
# 1      Denmark  Happiness_Rank    2.0
# 2      Iceland  Happiness_Rank    3.0
# 3  Switzerland  Happiness_Rank    4.0
# 4      Finland  Happiness_Rank    5.0
# 5  Netherlands  Happiness_Rank    6.0
# 6       Canada  Happiness_Rank    7.0

# %%
data['NatLan']=np.nan
data.head()
# Out:
#        Country  Happiness_Rank  Happiness_Score  Whisker_high  Whisker_low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy_GDP    Family  Health_Life_Expectancy   Freedom  Generosity  \
# 0     1.616463  1.533524                0.796667  0.635423    0.362012
# 1     1.482383  1.551122                0.792566  0.626007    0.355280
# 2     1.480633  1.610574                0.833552  0.627163    0.475540
# 3     1.564980  1.516912                0.858131  0.620071    0.290549
# 4     1.443572  1.540247                0.809158  0.617951    0.245483
#
#    Trust_Government_Corruption  Dystopia_Residual  NatLan
# ...

# %%
data.NatLan=['Low' if a<1.5 else 'High' for a in data.Family]
data[data.NatLan=='High']
#data.tail()
# Out:
#         Country  Happiness_Rank  Happiness_Score  Whisker_high  Whisker_low  \
# 0        Norway               1            7.537      7.594445     7.479556
# 1       Denmark               2            7.522      7.581728     7.462272
# 2       Iceland               3            7.504      7.622030     7.385970
# 3   Switzerland               4            7.494      7.561772     7.426227
# 4       Finland               5            7.469      7.527542     7.410458
# 7   New Zealand               8            7.314      7.379510     7.248490
# 9     Australia              10            7.284      7.356651     7.211349
# 14      Ireland              15            6.977      7.043352     6.910649
# 33        Spain              34            6.403      6.471055     6.334945
# 39     Slovakia              40            6.098      6.177348     6.018652
# 46   Uzbekistan              47            5.971      6.065538     5.876463
# ...
